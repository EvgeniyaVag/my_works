# %% [markdown]
# Будем работать с датасетом Pima Indian Diabetes - это набор данных из Национального института диабета, болезней органов пищеварения и почек. Целью набора данных является диагностическое прогнозирование наличия диабета у пациента. Несколько ограничений были наложены на выбор этих экземпляров из большой базы данных. В частности, все пациенты здесь - женщины в возрасте от 21 года, индийского происхождения.

# %% [markdown]
# Описание данных:Pregnancies, Glucose, BloodPressure, SkinThickness, Insulin, Age
#
# - __Pregnancies__ - данная единица отображает количество беременностей, единицы измерения - целые числа от 0 до N. Тип переменной - количественная, дискретная.
# - __Glucose__ - данная единица отображает уровень глюкозы в крови, единицы измерения - целые числа. Тип переменной - количественная, дискретная.
# - __BloodPressure__ - данная единица отображает артериальное давление, единицы измерения - миллиметры р/с, целые числа. Тип переменной - количественная, дискретная.
# - __SkinThickness__ - данная единица отображает обхват трицепса в миллиметрах, целые числа. Тип переменной - количественная, дискретная.
# - __Insulin__ - данная единица отображает уровень инсулина в крови, целые числа. Тип переменной - количественная, дискретная.
# - __BMI__ - данная единица отображает индекс массы тела. Тип переменной - количественная, непрерывная.
# - __DiabetesPedigreeFunction__ - данная единица отображает риск наследственного диабета в зависимости наличия диабета у родственников. Выражается десятичной дробью от 0 до 1. Тип переменной - количественная, непрерывная.
# - __Age__ - данная единица отражает возраст в целых числах. Тип переменной - количественная, дискретная.
# - __Class__ - данная единица отражает наличие диабета у субъекта, выражена 0(здоров) или 1(болен). Тип переменной - категориальная, бинарная.

# %%
# Подключение библиотек

import pandas as pd
import numpy as np

df = pd.read_csv('/content/06.10.23+dataset_diabet.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0      NaN  33.6
# 1              1     85.0           66.0           29.0      NaN  26.6
# 2              8    183.0           64.0            NaN      NaN  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0      NaN  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0            NaN      NaN  30.1
# 767            1     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Class
# 0                       0.627   50      1
# ...

# %% [markdown]
# **Задание 1.** Посчитайте количество пропусков в каждом из столбцов.

# %%
df.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Class                         0
# dtype: int64

# %% [markdown]
# **Задание 2.** Замените все пропуски дискретных признаков соответствующими медианами, непрерывных признаков - средними значениями.

# %%
#Ваш код здесь
#для заполнения пропусков воспользуйтесь методом fillna()
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Class'],
#       dtype='object')

# %%
median_all = df[['Glucose', 'BloodPressure', 'SkinThickness',\
                 'Insulin']].median()
median_all
# Out:
# Glucose          117.0
# BloodPressure     72.0
# SkinThickness     29.0
# Insulin          125.0
# dtype: float64

# %%
#df.median_all.fillna() #[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',]]
df = df.fillna(median_all)

# %%
df.isna().sum()
# Out:
# Pregnancies                  0
# Glucose                      0
# BloodPressure                0
# SkinThickness                0
# Insulin                      0
# BMI                         11
# DiabetesPedigreeFunction     0
# Age                          0
# Class                        0
# dtype: int64

# %%
mean_all = df[['BMI']].mean().round(2)
mean_all
# Out:
# BMI    32.46
# dtype: float64

# %%
df = df.fillna(mean_all)

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Class                       0
# dtype: int64

# %% [markdown]
# **Задание 3.** Вычислите основные статистики (минимум, максимум, среднее, дисперсию, квантили) для всех столбцов.

# %%
df.describe().round(2)
# Out:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin     BMI  \
# count       768.00   768.00         768.00         768.00   768.00  768.00
# mean          3.85   121.66          72.39          29.11   140.67   32.46
# std           3.37    30.44          12.10           8.79    86.38    6.88
# min           0.00    44.00          24.00           7.00    14.00   18.20
# 25%           1.00    99.75          64.00          25.00   121.50   27.50
# 50%           3.00   117.00          72.00          29.00   125.00   32.40
# 75%           6.00   140.25          80.00          32.00   127.25   36.60
# max          17.00   199.00         122.00          99.00   846.00   67.10
#
#        DiabetesPedigreeFunction     Age   Class  wasPregnant
# count                    768.00  768.00  768.00       768.00
# mean                       0.47   33.24    0.35         0.86
# std                        0.33   11.76    0.48         0.35
# ...

# %% [markdown]
# **Задание 4.** У скольких женщин старше 50 лет обнаружен диабет?

# %%
select_rows = df[(df.Class == 1)&(df.Age > 50)].DiabetesPedigreeFunction.count()
print(f'У {select_rows} женщин старше 50 обнаружен диабет.')
# Out:
# У 38 женщин старше 50 обнаружен диабет.

# %% [markdown]
# **Задание 5.** Найдите трех женщин с наибольшим числом беременностей.

# %%
df.groupby('Pregnancies')['Class'].count().sort_index(ascending = False)[:3]
# Out:
# Pregnancies
# 17    1
# 15    1
# 14    2
# Name: Class, dtype: int64

# %% [markdown]
# **Задание 6.** Сколько женщин возраста между 30 и 40 успело родить 3 или более детей?

# %%
female_ch = df[(df.Pregnancies >= 3)&(df.Age.between(30,40))].DiabetesPedigreeFunction.count()
print(f'У {female_ch} женщин в возрасте 30-40 лет есть 3 и более детей.')
# Out:
# У 142 женщин в возрасте 30-40 лет есть 3 и более детей.

# %% [markdown]
# **Задание 7.** Нормальным кровяным давлением будем считать давление в диапазоне [80-89]. У какого процента женщин давление нормальное?

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Class'],
#       dtype='object')

# %%
female_press = df[(df.BloodPressure.between(80,89))].DiabetesPedigreeFunction.count()
print(f'Нормальное давление у {(female_press*100/768).round(2)}% женщин')
# Out:
# Нормальное давление у 18.88% женщин

# %% [markdown]
# **Задание 8.** Считается, что BMI >= 30 - это признак ожирения.
# У скольких женщин с признаками ожирения кровяное давление выше среднего?

# %%
female_BMI = df[(df.BMI >= 30)&(df.BloodPressure>(df.BloodPressure.mean()))].DiabetesPedigreeFunction.count()
print(f'У {female_BMI} женщин с признаками ожирения кровяное давление выше среднего')
# Out:
# У 251 женщин с признаками ожирения кровяное давление выше среднего

# %% [markdown]
# **Задание 9.** Сравните средние значения для признаков __Glucose,	BloodPressure,	Insulin__ среди тех, у кого обнаружен диабет, и тех, у кого его нет.

# %%
#Первый способ для размышления
tabl_diabet = df[df['Class'] == 1].head(3)
tabl_diabet
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Class
# 0                     0.627   50      1
# 2                     0.672   32      1
# 4                     2.288   33      1

# %%
tabl_non_diabet = df[df['Class'] == 0].head(3)
tabl_non_diabet
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1     85.0           66.0           29.0    125.0  26.6
# 3            1     89.0           66.0           23.0     94.0  28.1
# 5            5    116.0           74.0           29.0    125.0  25.6
#
#    DiabetesPedigreeFunction  Age  Class
# 1                     0.351   31      0
# 3                     0.167   21      0
# 5                     0.201   30      0

# %%
mean_GBI_1 = tabl_diabet[['Glucose', 'BloodPressure', 'Insulin']].mean().round(2)
mean_GBI_1
# Out:
# Glucose          156.00
# BloodPressure     58.67
# Insulin          139.33
# dtype: float64

# %%
mean_GBI_2 = tabl_non_diabet[['Glucose', 'BloodPressure', 'Insulin']].mean().round(2)
mean_GBI_2
# Out:
# Glucose           96.67
# BloodPressure     68.67
# Insulin          114.67
# dtype: float64

# %%
#Второй способ, но почему-то значения разные
df.pivot_table(index = 'Class',
               #columns = ,
               values = ['Glucose', 'BloodPressure', 'Insulin'],
               aggfunc = 'mean').round(2)#.reset_index()
# Out:
#        BloodPressure  Glucose  Insulin
# Class
# 0              70.92   110.68   127.79
# 1              75.12   142.13   164.70

# %% [markdown]
# **Задание 10.** Добавьте новый бинарный признак:
#
# __wasPregnant__ $\in$ {0,1} - была женщина беременна (1) или нет (0)

# %%
df['wasPregnant'] = np.where(df['Pregnancies'] > 0, 1, 0)
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Class  wasPregnant
# 0                     0.627   50      1            1
# 1                     0.351   31      0            1
# 2                     0.672   32      1            1
# 3                     0.167   21      0            1
# 4                     2.288   33      1            0

# %% [markdown]
# **Задание 11.** Сравните процент больных диабетом среди женщин, которые были беременны и не были.

# %%
#Вариант 1
female_boln_pr = df[(df.Class == 1)&(df.wasPregnant == 1)].DiabetesPedigreeFunction.count()
female_boln2_ne_pr = df[(df.Class == 1)&(df.wasPregnant == 0)].DiabetesPedigreeFunction.count()
print(f'Болели диабетом и были беременны - {female_boln_pr},\
 болели диабетом и не были беременны - {female_boln2_ne_pr}')

print(f'Всего больных диабетом - {female_boln_pr+female_boln2_ne_pr}')

print(f'Больные диабетом, которые были беременные - {(female_boln_pr*100/(female_boln_pr+female_boln2_ne_pr)).round(2)}%\n\
Больные диабетом, которые не были беременные - {(female_boln2_ne_pr*100/(female_boln_pr+female_boln2_ne_pr)).round(2)}%')
# Out:
# Болели диабетом и были беременны - 230, болели диабетом и не были беременны - 38
# Всего больных диабетом - 268
# Больные диабетом, которые были беременные - 85.82%
# Больные диабетом, которые не были беременные - 14.18%

# %%
#Вариант 2 - как здесь округлить до 2 знаков не поняла, не получилось...
a = len(df[(df.Pregnancies > 0)&(df.Class == 1)])/len(df[df.Class == 1])
b = len(df[(df.Pregnancies == 0)&(df.Class == 1)])/len(df[df.Class == 1])
print(f'{(a*100)}%\n{b*100}%')
# Out:
# 85.82089552238806%
# 14.17910447761194%

# %% [markdown]
# **Задание 12.** Добавьте новый категориальный признак __bodyType__ на основе столбца BMI:
#
# __BMI Categories:__
#
# Underweight = <18.5
#
# Normal weight = 18.5–24.9
#
# Overweight = 25–29.9
#
# Obesity = BMI of 30 or greater
#
# Признак должен принимать значения Underweight, Normal weight, Overweight и Obesity.

# %%
def bodyType(BMI):

  if BMI <= 18.5:
    return ('Underweight')
  elif 18.6 <= BMI <= 24.9:
    return ('Normal weight')
  elif 25 <= BMI <= 29.9:
    return ('Overweight')
  elif BMI >= 30:
    return ('Obesity')

df['bodyType'] = df['BMI'].apply(bodyType)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    125.0  33.6
# 1              1     85.0           66.0           29.0    125.0  26.6
# 2              8    183.0           64.0           29.0    125.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0    125.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           29.0    125.0  30.1
# 767            1     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  Class       bodyType
# 0                       0.627   50      1        Obesity
# ...

# %% [markdown]
# **Задание 13.** Будем считать "здоровыми" тех, у кого нормальный вес и кровяное давление. Какой процент "здоровых" женщин больны диабетом?

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Class', 'bodyType'],
#       dtype='object')

# %%
female_zdorovue = df[(df.bodyType == 'Normal weight')&(df.BloodPressure.between(80,89))].DiabetesPedigreeFunction.count()
female_zdorovue
# Out:
# 10

# %%
zdor_s_diab = df[(female_zdorovue)&(df.Class == 1)].DiabetesPedigreeFunction.count()
print(f'"Здоровых" женщин с диабетом {zdor_s_diab}')
# Out:
# "Здоровых" женщин с диабетом 0
